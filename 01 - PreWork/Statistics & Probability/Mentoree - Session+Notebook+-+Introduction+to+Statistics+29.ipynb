# %% [markdown]
# <font size ="8"> <div align="center"><div class="alert alert-block alert-success">**Introduction to Statistics**</div></font>

# %% [markdown]
# -----
# # **Context**
# -----
#
# **WOW Superstore** sells different products like office supplies, furniture and appliances. For each order that is placed, the superstore keeps a record of various attributes related to the product, like state, city, category, subcategory and quantity.
#
# **Each row of the data corresponds to a unique order placed.** The detailed description of the attributes recorded are given below:
#
# -----
# ## **Data Description**
# -----
#
# 1. **Order ID:** Unique ID for an order
# 2. **Ship Mode:** Mode of shipping used for shipment delivery
# 3. **Segment:** Customer segment product was shipped to
# 4. **City:** City in which shipment was delivered
# 5. **State:** State in which the shipment was delivered
# 6. **Region:** State region
# 7. **Category:** The category product belongs to
# 8. **Sub-Category:** Sub-category of the product
# 9. **Sales:** Sale made in USD
# 10. **Quantity:** Product quantity
# 11. **Discount:** Discount given on the product
# 12. **Profit:** Profit/loss made on the sale

# %% [markdown]
# ![maxresdefault.jpg](attachment:maxresdefault.jpg)

# %% [markdown]
# ### **We will first import the Python libraries needed for our analysis**

# %%
# Load the Pandas library with alias 'pd' - to import and analyze tabular data
import pandas as pd

# Load the Seaborn library with alias 'sns' -to create visualizations
import seaborn as sns

# Load Matplotlib Library
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-block alert-danger"> ModuleNotFoundError: No module named 'pandas'<div>

# %% [markdown]
# When you see this error it means pandas is not installed in your python

# %% [markdown]
# <mark style="background-color: lightyellow"> <font size = "5"> *pip install pandas* </font></mark>

# %% [markdown]
# <font size ="3"> How to check if pandas got installed? </br>

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.1'

# %% [markdown]
# ### **Let's load the data into a pandas dataframe for analysis**

# %% [markdown]
# <mark style="background-color: lightyellow"> When you specify a filename to *pandas.read_csv()*, Python will look in your current working directory. Your working directory is typically the directory that you started your Python process or Jupyter notebook from.</mark>

# %%
# Read data from file 'WOW Superstore.csv' 
# (in the same directory that your python process is based)

data = pd.read_csv("WOWSuperstore.csv")

# %% [markdown]
# Please ensure the following:
# 1. Data that you have downloaded from Olympus and the new jupyter notebook you have created are in the same folder.
# 2. Ensure that the name of the dataset is correct - check for lowercase and uppercase, check for spaces, name of the data set (.csv file), etc.

# %% [markdown]
# ### **Before we begin our analysis, let's take a quick look at our data to get a feel for it**

# %% [markdown]
# <mark style="background-color: lightyellow"> We can check the first 5 rows of the data using the *head()* function.</mark>

# %%
data.head()
# Out:
#     Order ID       Ship Mode      Segment          City         State
# 0  WOWID0001  Standard Class     Consumer       Seattle    Washington  \
# 1  WOWID0002  Standard Class  Home Office    Fort Worth         Texas
# 2  WOWID0003  Standard Class  Home Office    Fort Worth         Texas
# 3  WOWID0004  Standard Class     Consumer  Philadelphia  Pennsylvania
# 4  WOWID0005  Standard Class     Consumer  Philadelphia  Pennsylvania
#
#     Region         Category Sub-Category    Sales  Quantity  Discount
# 0     West  Office Supplies      Binders  407.976         3       0.2  \
# 1  Central  Office Supplies   Appliances   68.810         5       0.8
# 2  Central  Office Supplies      Binders    2.544         3       0.8
# 3     East        Furniture    Bookcases      NaN         7       0.5
# 4     East  Office Supplies      Binders    9.618         2       0.7
#
#       Profit
# 0   132.5922
# 1  -123.8580
# 2    -3.8160
# 3 -1665.0522
# 4    -7.0532

# %% [markdown]
# * We can check the last 5 rows of the data using the *tail()* function.

# %%
data.tail()
# Out:
#        Order ID       Ship Mode      Segment          City         State
# 1945  WOWID1946  Standard Class    Corporate  Philadelphia  Pennsylvania  \
# 1946  WOWID1947  Standard Class    Corporate  Philadelphia  Pennsylvania
# 1947  WOWID1948     First Class  Home Office       Houston         Texas
# 1948  WOWID1949     First Class  Home Office       Houston         Texas
# 1949  WOWID1950  Standard Class     Consumer       Houston         Texas
#
#        Region         Category Sub-Category     Sales  Quantity  Discount
# 1945     East  Office Supplies        Paper    3.4240         1      0.20  \
# 1946     East       Technology  Accessories  151.2000         3      0.20
# 1947  Central  Office Supplies        Paper   65.5840         2      0.20
# 1948  Central        Furniture    Bookcases  383.4656         4      0.32
# 1949  Central  Office Supplies    Envelopes   99.5680         2      0.20
#
#        Profit
# 1945   1.0700
# 1946  32.1300
# 1947  23.7742
# 1948 -67.6704
# 1949  33.6042

# %%
# from online class
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 🤓 <font color='Blue'> *Your turn to code!* </font>

# %%
# how can we check the first 10 rows of the data?
data.head(10)
# Out:
#     Order ID       Ship Mode      Segment          City         State
# 0  WOWID0001  Standard Class     Consumer       Seattle    Washington  \
# 1  WOWID0002  Standard Class  Home Office    Fort Worth         Texas
# 2  WOWID0003  Standard Class  Home Office    Fort Worth         Texas
# 3  WOWID0004  Standard Class     Consumer  Philadelphia  Pennsylvania
# 4  WOWID0005  Standard Class     Consumer  Philadelphia  Pennsylvania
# 5  WOWID0006  Standard Class     Consumer  Philadelphia  Pennsylvania
# 6  WOWID0007  Standard Class     Consumer  Philadelphia  Pennsylvania
# 7  WOWID0008  Standard Class     Consumer  Philadelphia  Pennsylvania
# 8  WOWID0009  Standard Class     Consumer  Philadelphia  Pennsylvania
# 9  WOWID0010  Standard Class     Consumer  Philadelphia  Pennsylvania
#
#     Region         Category Sub-Category    Sales  Quantity  Discount
# 0     West  Office Supplies      Binders  407.976         3       0.2  \
# 1  Central  Office Supplies   Appliances   68.810         5       0.8
# 2  Central  Office Supplies      Binders    2.544         3       0.8
# 3     East        Furniture    Bookcases      NaN         7       0.5
# 4     East  Office Supplies      Binders    9.618         2       0.7
# 5     East        Furniture  Furnishings  124.200         3       0.2
# 6     East  Office Supplies    Envelopes    3.264         2       0.2
# 7     East  Office Supplies          Art   86.304         6       0.2
# 8     East  Office Supplies      Binders    6.858         6       0.7
# 9     East  Office Supplies          Art   15.760         2       0.2
#
#       Profit
# 0   132.5922
# 1  -123.8580
# 2    -3.8160
# 3 -1665.0522
# 4    -7.0532
# 5    15.5250
# 6     1.1016
# 7     9.7092
# 8    -5.7150
# 9     3.5460

# %% [markdown]
# * We can check a **random sample** of rows of the data using the *sample()* function.
# * We will set the *n* parameter to 5 to display 5 random rows.
# * Note that **the sample rows displayed will change each time we execute the code,** since a random selection is executed.

# %%
data.sample(n=5)
# Out:
#        Order ID       Ship Mode    Segment           City         State
# 1442  WOWID1443  Standard Class  Corporate   Philadelphia  Pennsylvania  \
# 449   WOWID0450  Standard Class  Corporate         Austin         Texas
# 1367  WOWID1368     First Class  Corporate        Chester  Pennsylvania
# 550   WOWID0551  Standard Class  Corporate  Highland Park      Illinois
# 1932  WOWID1933     First Class   Consumer       La Porte         Texas
#
#        Region         Category Sub-Category    Sales  Quantity  Discount
# 1442     East  Office Supplies      Storage  147.184         2       0.2  \
# 449   Central  Office Supplies    Fasteners    2.896         2       0.2
# 1367     East  Office Supplies      Binders    8.595         5       0.7
# 550   Central        Furniture       Chairs  539.658         3       0.3
# 1932  Central  Office Supplies      Binders   16.392         2       0.8
#
#        Profit
# 1442 -29.4368
# 449    0.4706
# 1367  -6.3030
# 550   -7.7094
# 1932 -26.2272

# %% [markdown]
# **What does this quick look at our data tell us?**
#
# * Two modes of shipping are visible - *Standard Class* and *First Class*.
# * Three customer segments are visible - *Consumer*, *Corporate*, and *Home Office*.
# * The customers are spread across different cities and states of the US.
# * The products ordered belong to various categories like *Office Supplies*, *Furniture*, *Technology* etc.
# * The discounts provided range from 20% to 80%.
# * The *Profit* column has negative values too, indicating losses incurred.
#
# <mark style="background-color: lightyellow"> This, of course, is true **only for this snapshot of 15 rows** that we have just seen. We have some very handy fuctions in Pandas to do a thorough summary analysis of the entire data without having to view all the rows. </mark>

# %%
# From online class
data.sample(n=15)
# Out:
#        Order ID       Ship Mode      Segment           City         State
# 635   WOWID0636  Standard Class  Home Office        Seattle    Washington  \
# 1625  WOWID1626  Standard Class    Corporate   Philadelphia  Pennsylvania
# 326   WOWID0327  Standard Class    Corporate   Philadelphia  Pennsylvania
# 1889  WOWID1890     First Class     Consumer         Dallas         Texas
# 1162  WOWID1163  Standard Class     Consumer          Plano         Texas
# 1185  WOWID1186  Standard Class     Consumer  Grand Prairie         Texas
# 477   WOWID0478  Standard Class     Consumer         Dallas         Texas
# 130   WOWID0131     First Class  Home Office        Chester  Pennsylvania
# 638   WOWID0639  Standard Class     Consumer        Seattle    Washington
# 305   WOWID0306  Standard Class    Corporate      Grapevine         Texas
# 1819  WOWID1820  Standard Class     Consumer     Carrollton         Texas
# 1355  WOWID1356  Standard Class     Consumer   Philadelphia  Pennsylvania
# 272   WOWID0273  Standard Class     Consumer        Seattle    Washington
# 791   WOWID0792  Standard Class     Consumer        Chester  Pennsylvania
# 163   WOWID0164     First Class  Home Office   Philadelphia  Pennsylvania
#
#        Region         Category Sub-Category    Sales  Quantity  Discount
# 635      West       Technology       Phones  105.584         2       0.2  \
# 1625     East  Office Supplies      Binders   26.388         4       0.7
# 326      East       Technology       Phones  677.580         5       0.4
# 1889  Central        Furniture       Tables  307.314         3       0.3
# 1162  Central  Office Supplies       Labels   13.216         4       0.2
# 1185  Central  Office Supplies   Appliances   19.432         2       0.8
# 477   Central  Office Supplies      Storage  153.584         2       0.2
# 130      East  Office Supplies          Art    2.696         1       0.2
# 638      West  Office Supplies      Binders   19.296         3       0.2
# 305   Central  Office Supplies          Art   33.488         7       0.2
# 1819  Central       Technology  Accessories   47.904         1       0.2
# 1355     East       Technology      Copiers  599.970         5       0.4
# 272      West  Office Supplies      Binders   55.424         2       0.2
# 791      East        Furniture       Chairs  853.930         5       0.3
# 163      East       Technology       Phones  280.782         3       0.4
#
#         Profit
# 635     7.9188
# 1625  -17.5920
# 326  -158.1020
# 1889  -39.5118
# 1162    4.2952
# 1185  -49.5516
# 477   -32.6366
# 130     0.8088
# 638     6.0300
# 305     5.8604
# 1819   -2.9940
# 1355   69.9965
# 272    19.3984
# 791     0.0000
# 163   -46.7970

# %% [markdown]
# ### **Now that we have taken a quick look at our data, let's check the number of rows and columns in the data, and what type of values we are going to deal with**
#
# * The *shape* attribute and the *info()* function will help us with this.

# %%
# checking the shape of the data
print ("The number of rows in the data is", data.shape[0], "and the number of columns are", data.shape[1])
# Out:
# The number of rows in the data is 1950 and the number of columns are 12

# %%
# From online class
data.shape
# Out:
# (1950, 12)

# %% [markdown]
# * We see that there are 1950 rows and 12 columns in the data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1950 entries, 0 to 1949
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1950 non-null   object
#  1   Ship Mode     1950 non-null   object
#  2   Segment       1950 non-null   object
#  3   City          1950 non-null   object
#  4   State         1950 non-null   object
#  5   Region        1950 non-null   object
#  6   Category      1950 non-null   object
#  7   Sub-Category  1950 non-null   object
#  8   Sales         1948 non-null   float64
#  9   Quantity      1950 non-null   int64
#  10  Discount      1950 non-null   float64
#  11  Profit        1950 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 182.9+ KB

# %% [markdown]
# <mark style="background-color: lightyellow">
# - There are columns of different types in the data. </br>
# - Sales, Discount, and Profit are float type columns. </br>
# - Quantity is an int type column. </br>
# - The rest of the columns are of the *object* data type.</br>

# %% [markdown]
# ### <font color='Blue'> How to check for missing values?

# %%
data.isnull().sum()
# Out:
# Order ID        0
# Ship Mode       0
# Segment         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           2
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# <mark style="background-color: lightyellow">
# - There are 2 missing values in the sales column. </br>

# %% [markdown]
# # <div class="alert alert-block alert-success"> 💬 Discuss </div>

# %% [markdown]
# ### How would you tread the 2 missing values ?
# - Drop them?
# - Replace them with mean?
# - Replace them with median?

# %% [markdown]
# <div class="alert alert-block alert-success"> You would learn about handling missing values in coming lectures for now less us drop these values </div>

# %%
data.dropna(inplace= True)

# %%
data.isnull().sum()
# Out:
# Order ID        0
# Ship Mode       0
# Segment         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# What is the shape of dataframe now?

# %%
data.shape
# Out:
# (1948, 12)

# %% [markdown]
# ### **We now know how many and what type of values we are going to deal with. It's time to proceed with our analysis.**
#
# #### Summary statistics are a good place to start an analysis. Pandas provides a neat statistical summary of the data through the *describe()* function. Let's take a look at it.

# %%
# Compute the basic statistic for numerical column
data.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   1948.000000  1948.000000  1948.000000  1948.000000
# mean     190.353036     3.742813     0.311006    -7.919223
# std      537.082847     2.143557     0.245004   234.092099
# min        0.444000     1.000000     0.000000 -3701.892800
# 25%       12.618000     2.000000     0.200000   -12.283575
# 50%       41.178000     3.000000     0.200000     1.823600
# 75%      172.740000     5.000000     0.400000    10.137750
# max    13999.960000    14.000000     0.800000  6719.980800

# %% [markdown]
# - The sale amount of products varies from 0.44 to ~14000 dollars.
# - The order quantity varies from 1 to 14 units.
# - The discount on products varies from 0 to 80%.
# - The *Profit* column has negative values, indicating losses incurred.

# %% [markdown]
# <font size= "4"> What are your insights? </font>

# %% [markdown]
# # <font color='blue'>Question:</font>
#
# ### What is the average discount offered across all orders?
#
# 1. **Approx. 31%** <--
# 2. Approx. 24.5%
# 3. Approx. 20%
# 4. Approx. 80%

# %% [markdown]
# * The above summary shows only the numerical columns.
# * Can we include the non-numerical columns too? - YES! Let's set the *include* parameter of the *describe()* function to *'all'*.
# * We will also transpose the data using the *T* attribute to make it easier to view the whole summary at once.

# %%
# top --> mode
data.describe(include="all").T
# Out:
#                count unique              top  freq        mean         std
# Order ID        1948   1948        WOWID0001     1         NaN         NaN  \
# Ship Mode       1948      2   Standard Class  1561         NaN         NaN
# Segment         1948      3         Consumer  1022         NaN         NaN
# City            1948    105     Philadelphia   436         NaN         NaN
# State           1948      4            Texas   745         NaN         NaN
# Region          1948      3          Central  1107         NaN         NaN
# Category        1948      3  Office Supplies  1200         NaN         NaN
# Sub-Category    1948     17          Binders   342         NaN         NaN
# Sales         1948.0    NaN              NaN   NaN  190.353036  537.082847
# Quantity      1948.0    NaN              NaN   NaN    3.742813    2.143557
# Discount      1948.0    NaN              NaN   NaN    0.311006    0.245004
# Profit        1948.0    NaN              NaN   NaN   -7.919223  234.092099
#
#                     min        25%     50%       75%        max
# Order ID            NaN        NaN     NaN       NaN        NaN
# Ship Mode           NaN        NaN     NaN       NaN        NaN
# Segment             NaN        NaN     NaN       NaN        NaN
# City                NaN        NaN     NaN       NaN        NaN
# State               NaN        NaN     NaN       NaN        NaN
# Region              NaN        NaN     NaN       NaN        NaN
# Category            NaN        NaN     NaN       NaN        NaN
# Sub-Category        NaN        NaN     NaN       NaN        NaN
# Sales             0.444     12.618  41.178    172.74   13999.96
# Quantity            1.0        2.0     3.0       5.0       14.0
# Discount            0.0        0.2     0.2       0.4        0.8
# Profit       -3701.8928 -12.283575  1.8236  10.13775  6719.9808

# %% [markdown]
# - There are two shipment modes, '*Standard Class*' being the more frequent one.
# - Orders were shipped across 3 regions, 4 states, and 105 cities. '*Philadelphia*' was the most frequent city for shipping.
# - The products are spread across 3 categories and 17 sub-categories.

# %% [markdown]
# # <font color='blue'>Question:</font>
#
# ### How many distinct segments of customers are present in the data?
#
# 1. 2
# 2. **3** <--
# 3. 4
# 4. 5

# %%
data["Segment"].unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %% [markdown]
# ### **The statistical summary was really helpful. The next step would be to analyze some of the columns individually to see if we can gain more insights.**
#
# ### **We will begin with the categorical variables in the data.**

# %% [markdown]
# * Let's check the unique value in the *Category* column.
# * The Pandas *unique()* function will help us here.

# %%
data["Category"].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %% [markdown]
# * Let's check the number of orders corresponding to each unique value in the *Category* column.
# * The *value_counts()* function in Pandas allows us to do this.

# %%
data["Category"].value_counts()
# Out:
# Category
# Office Supplies    1200
# Furniture           410
# Technology          338
# Name: count, dtype: int64

# %% [markdown]
# **Observations**
#
# - There are 3 categories of products.
# - Most of the orders are for products under the category *Office Supplies*.

# %% [markdown]
# **Let's check the unique value in the *State* column.**

# %%
data["State"].unique()
# Out:
# array(['Washington', 'Texas', 'Pennsylvania', 'Illinois'], dtype=object)

# %% [markdown]
# ### 🤓 <font color='Blue'> *Your turn to code!* </font>

# %% [markdown]
# **Check the number of orders corresponding to each unique value of the *State* column.**

# %%
# From online classes
data["State"].value_counts()
# Out:
# State
# Texas           745
# Pennsylvania    479
# Washington      362
# Illinois        362
# Name: count, dtype: int64

# %%
data[['Order ID', 'State']].groupby(['State']).agg(['count'])
# Out:
#              Order ID
#                 count
# State
# Illinois          362
# Pennsylvania      479
# Texas             745
# Washington        362

# %%
data[['Order ID', 'State']].groupby(['State']).count()
# Out:
#               Order ID
# State
# Illinois           362
# Pennsylvania       479
# Texas              745
# Washington         362

# %%
data.groupby(['State'])['Order ID'].describe()[['count']]
# Out:
#              count
# State
# Illinois       362
# Pennsylvania   479
# Texas          745
# Washington     362

# %%
data.groupby(['State'])['Order ID'].describe().sort_values(by=['count'], ascending=False)
# Out:
#              count unique        top freq
# State
# Texas          745    745  WOWID0002    1
# Pennsylvania   479    479  WOWID0005    1
# Illinois       362    362  WOWID0017    1
# Washington     362    362  WOWID0001    1

# %% [markdown]
# # <font color='blue'>Question:</font>
#
# ### Which state were most of the orders placed from?
#
# 1. Texas <---
# 2. Pennsylvania
# 3. Illinois
# 4. Washington

# %% [markdown]
# ### **Now let's analyze some of the numerical variables in the data.**

# %% [markdown]
# * Let's check the average profit across all the orders.
# * The *mean()* function can be used for this.

# %%
data["Profit"].mean()
# Out:
# -7.919223305954826

# %% [markdown]
# * Let's check the maximum profit across all the orders.
# * The *max()* function can be used for this.

# %%
data["Profit"].max()
# Out:
# 6719.9808

# %% [markdown]
# * Let's check the minimum profit across all the orders.
# * The *min()* function can be used for this.

# %%
data["Profit"].min()
# Out:
# -3701.8928

# %% [markdown]
# **Observations**
#
# * On an average, the orders have resulted in a loss of 8.7 dollars to the superstore.
# * The maximum profit made was ~6720 dollars, while the maximum loss incurred was ~3700 dollars.

# %% [markdown]
# ### **That gives us an overall idea of how the superstore is performing in financial terms. Let's dig a little deeper now.**

# %% [markdown]
# * Let's check the average profit across the different product categories and different states.
# * To do so, we will have to first group the data with respect to a particular variable and then check the average profit.
# * The *groupby()* function in Pandas will help us group the data with respect to a particular variable.

# %%
# checking the average profit across the different product categories
data.groupby("Category")["Profit"].mean()
# Out:
# Category
# Furniture         -31.128864
# Office Supplies   -15.013882
# Technology         45.422622
# Name: Profit, dtype: float64

# %%
# From online class
data.groupby("Category")["Profit"].count()
# Out:
# Category
# Furniture           410
# Office Supplies    1200
# Technology          338
# Name: Profit, dtype: int64

# %% [markdown]
# * Products under the *Furniture* category result in more losses on average, while products under the *Technology* category result in more profits on average.

# %%
# checking the average profit across the different states
data.groupby("State")["Profit"].mean().sort_values(ascending=False)
# Out:
# State
# Washington      73.147109
# Pennsylvania   -18.826783
# Texas          -29.594339
# Illinois       -29.944996
# Name: Profit, dtype: float64

# %% [markdown]
# * Here we also sorted the data in descending order of values using the *sort_values()* function.
# * Orders placed from the state of Washington result in more profits on average, while those placed from the state of Illinois result in more losses on average.

# %% [markdown]
# ### **We saw that the orders placed from the state of Washington result in more profits. Lets see the distribution of product categories across the different states to gain more insights.**

# %% [markdown]
# * We will use the *crosstab()* function of pandas to check the the distribution of product categories across the different states.

# %%
data_cross = pd.crosstab(data["State"], data["Category"])
data_cross
# Out:
# Category      Furniture  Office Supplies  Technology
# State
# Illinois             91              216          55
# Pennsylvania         95              290          94
# Texas               150              471         124
# Washington           74              223          65

# %% [markdown]
# * We can display the above crosstab in a more visually appealing manner using a heatmap.
# * The *heatmap()* function in the Seaborn library will help us do so.

# %%
sns.heatmap(data_cross, annot=True, fmt=".0f", cmap="PuBu")
plt.show()

# %% [markdown]
# * Most orders are for office supplies across all the states, where Texas has the highest number of orders.
# * The distribution of *Furniture* and *Technology* products are similar for all states except Illinois.

# %% [markdown]
# ### **We can communicate our insights in a clearer and more visually appealing manner with visualizations instead of numbers.**
#
# #### Let's visualize the data a little more.

# %% [markdown]
# * Pair plots are a very informative type of visualization for numerical variables.
# * Let's see what insights we can get from it.

# %%
# list of numerical columns in the data
numerical_columns = ["Sales", "Quantity", "Discount", "Profit"]

sns.pairplot(data=data, vars=numerical_columns, diag_kind="kde", hue="Ship Mode")
plt.show()

# %%
from scipy.stats import pearsonr

def corrfunc(x, y, **kws):
    (r, p) = pearsonr(x, y)
    ax = plt.gca()
    #ax.annotate("r = {:.2f} ".format(r),
    #            xy=(.1, .9), xycoords=ax.transAxes)
    ax.annotate("p = {:.3f}".format(p), 
                xy=(.4, .9), xycoords=ax.transAxes)

    
graph = sns.pairplot(data=data, vars=numerical_columns, diag_kind="kde", hue="Ship Mode")
graph.map(corrfunc)
plt.show()

# %%
graph = sns.pairplot(data=data, vars=numerical_columns, kind="reg", hue="Ship Mode", 
                     plot_kws={'line_kws':{'linewidth':0.5}})
graph.map(corrfunc)
plt.show()

# %%
graph = sns.pairplot(data=data, vars=numerical_columns, kind="reg", hue="Ship Mode", 
                     corner=True,
                     plot_kws={'line_kws':{'linewidth':0.5}})
graph.map(corrfunc)
plt.show()

# %% [markdown]
# * We can see that a lot of orders are clustered between a profit or loss of 1000 dollars.
# * We can see that the distribution of the variables is similar for both shipment modes, but the number of orders are more for *Standard Class* shipping.
# * We had seen that the maximum profit made was ~6720 dollars, and the above plot shows that the order was shipped under *First Class*.

# %% [markdown]
# # <font color='blue'>Question:</font>
#
# ### We had seen that the maximum loss incurred was ~3700 dollars. Which shipping mode does that order correspond to?
#
# 1. **Standard Class** <--
# 2. First Class

# %%
data[data.Profit <= -3700]
# Out:
#        Order ID       Ship Mode   Segment         City  State   Region
# 1919  WOWID1920  Standard Class  Consumer  San Antonio  Texas  Central  \
#
#              Category Sub-Category     Sales  Quantity  Discount     Profit
# 1919  Office Supplies      Binders  2177.584         8       0.8 -3701.8928

# %% [markdown]
# ## Summary
# **Data description**
# * The dataset has **1950 observations and 12 columns.**
# * Sales, Discount, Profit, and Quantity are numerical columns while the rest are of the object datatype.
#
# **Insights from data exploration**
# * The sale amount of products varies from 0.44 to ~14000 dollars.
# * The minimum discount offered by the Superstore is 0% while the maximum is 80%.
# * The Profit column has negative values, indicating losses incurred.
# * 'Standard Class' is the most frequent mode of shipment and 'Philadelphia' is the most frequent city for shipping.
# * The products are spread across 3 categories and 17 sub-categories.
# * The orders are spread over 4 states - most of the orders are placed from the state of Texas and most orders are for office supplies.
# * Products under the Furniture category result in more losses on average, while Technology products tend to result in more profits.
# * Orders placed from the state of Washington result in more profits on average, while those placed from Illinois result in more losses.

# %% [markdown]
# ![home%20work.png](attachment:home%20work.png)

# %% [markdown]
# ###  Q1 Write a python code to visualise the count of city where the products were shipped.
#
# #### Hint : Use countplot

# %%
# from online class
data["City"].value_counts()
# Out:
# City
# Philadelphia       436
# Seattle            309
# Houston            273
# Chicago            226
# Dallas             122
#                   ...
# College Station      1
# Conroe               1
# Reading              1
# Danville             1
# Tinley Park          1
# Name: count, Length: 105, dtype: int64

# %%
# from online class
plt.figure(figsize=(15,4))
sns.countplot(x='City', data=data)
plt.xticks(fontsize=6, rotation=90)
plt.show()

# %%
data_cities = data[['Ship Mode', 'City']].groupby(['Ship Mode']).agg(**{'Cities': ('City', 'nunique')}).reset_index()
data_cities
# Out:
#         Ship Mode  Cities
# 0     First Class      49
# 1  Standard Class      93

# %%
sns.barplot(data=data_cities, x='Ship Mode', y='Cities')
plt.show()

# %%
sns.countplot(x = 'Ship Mode', data = data[['Ship Mode', 'City']].drop_duplicates().sort_values('Ship Mode'))
plt.show()

# %%
#fig, ax = plt.subplots(figsize=(6, 6))
#sns.barplot(x, y, ax=ax)

plt.figure(figsize=(15,22))
ax = sns.countplot(y='City', data=data,
                   order = data['City'].value_counts().index)
plt.show()

# %% [markdown]
# ###  Q2  Remove the blank and fill it to get the output as shown below:

# %%
data.select_dtypes(include="object")
# Out:
#        Order ID       Ship Mode      Segment          City         State
# 0     WOWID0001  Standard Class     Consumer       Seattle    Washington  \
# 1     WOWID0002  Standard Class  Home Office    Fort Worth         Texas
# 2     WOWID0003  Standard Class  Home Office    Fort Worth         Texas
# 4     WOWID0005  Standard Class     Consumer  Philadelphia  Pennsylvania
# 5     WOWID0006  Standard Class     Consumer  Philadelphia  Pennsylvania
# ...         ...             ...          ...           ...           ...
# 1945  WOWID1946  Standard Class    Corporate  Philadelphia  Pennsylvania
# 1946  WOWID1947  Standard Class    Corporate  Philadelphia  Pennsylvania
# 1947  WOWID1948     First Class  Home Office       Houston         Texas
# 1948  WOWID1949     First Class  Home Office       Houston         Texas
# 1949  WOWID1950  Standard Class     Consumer       Houston         Texas
#
#        Region         Category Sub-Category
# 0        West  Office Supplies      Binders
# 1     Central  Office Supplies   Appliances
# 2     Central  Office Supplies      Binders
# 4        East  Office Supplies      Binders
# 5        East        Furniture  Furnishings
# ...       ...              ...          ...
# 1945     East  Office Supplies        Paper
# 1946     East       Technology  Accessories
# 1947  Central  Office Supplies        Paper
# 1948  Central        Furniture    Bookcases
# 1949  Central  Office Supplies    Envelopes
#
# [1948 rows x 8 columns]

# %%
for i in data.select_dtypes(include="object"):
    print (data[i].value_counts())
    print ("****"*10)
# Out:
# Order ID
# WOWID0001    1
# WOWID1282    1
# WOWID1310    1
# WOWID1309    1
# WOWID1308    1
#             ..
# WOWID0647    1
# WOWID0646    1
# WOWID0645    1
# WOWID0644    1
# WOWID1950    1
# Name: count, Length: 1948, dtype: int64
# ****************************************
# Ship Mode
# Standard Class    1561
# First Class        387
# Name: count, dtype: int64
# ****************************************
# Segment
# Consumer       1022
# Corporate       587
# Home Office     339
# Name: count, dtype: int64
# ****************************************
# City
# Philadelphia       436
# Seattle            309
# Houston            273
# Chicago            226
# Dallas             122
#                   ...
# College Station      1
# Conroe               1
# Reading              1
# Danville             1
# Tinley Park          1
# Name: count, Length: 105, dtype: int64
# ****************************************
# State
# Texas           745
# Pennsylvania    479
# Washington      362
# Illinois        362
# Name: count, dtype: int64
# ****************************************
# Region
# Central    1107
# East        479
# West        362
# Name: count, dtype: int64
# ****************************************
# Category
# Office Supplies    1200
# Furniture           410
# Technology          338
# Name: count, dtype: int64
# ****************************************
# Sub-Category
# Binders        342
# Paper          237
# Storage        182
# Furnishings    176
# Phones         157
# Accessories    146
# Art            144
# Chairs         121
# Appliances      86
# Labels          69
# Tables          67
# Envelopes       55
# Fasteners       51
# Bookcases       46
# Supplies        34
# Machines        20
# Copiers         15
# Name: count, dtype: int64
# ****************************************
