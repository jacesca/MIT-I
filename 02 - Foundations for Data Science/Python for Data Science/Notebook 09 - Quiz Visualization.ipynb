# %% [markdown]
# # Quiz - Visualization
#
# ### Context
#
# - Assume yourself in a world where you can gain knowledge only by reading books.
# - Now, you are confused by the fact that you have 271 books and you can't read them all at once. You need to read the best books first.
# - So, you decide to analyze the data about these books to find out the top 10 books which you should read.
# - This dataset holds a list of 271 books in the field of computer science and programming-related topics.
# - The list of books was constructed using many popular websites that provide information on book ratings and of all the books on those websites the 271 most popular were selected.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/prog_book.csv')

# %%
df
# Out:
#      Rating  Reviews                                         Book_title  \
# 0      4.17     3829                              The Elements of Style
# 1      4.01     1406      The Information: A History, a Theory, a Flood
# 2      3.33        0       Responsive Web Design Overview For Beginners
# 3      3.97     1658  Ghost in the Wires: My Adventures as the World...
# 4      4.06     1325                                   How Google Works
# ..      ...      ...                                                ...
# 266    3.76        0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94       22                An Introduction to Database Systems
# 268    4.49       36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77        4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84        5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rating           271 non-null    float64
#  1   Reviews          271 non-null    int64
#  2   Book_title       271 non-null    object
#  3   Description      271 non-null    object
#  4   Number_Of_Pages  271 non-null    int64
#  5   Type             271 non-null    object
#  6   Price            271 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 14.9+ KB

# %%
df.describe(include='all')
# Out:
#             Rating      Reviews             Book_title  \
# count   271.000000   271.000000                    271
# unique         NaN          NaN                    271
# top            NaN          NaN  The Elements of Style
# freq           NaN          NaN                      1
# mean      4.067417   185.557196                    NaN
# std       0.290749   552.122252                    NaN
# min       3.000000     0.000000                    NaN
# 25%       3.915000     5.500000                    NaN
# 50%       4.100000    35.000000                    NaN
# 75%       4.250000   116.500000                    NaN
# max       5.000000  5938.000000                    NaN
#
#                                               Description  Number_Of_Pages  \
# count                                                 271       271.000000
# unique                                                270              NaN
# top     Learn You a Haskell for Great Good! is a fun, ...              NaN
# ...

# %% [markdown]
# ### Distribution of the column 'Price'

# %%
df.Rating.hist()
# Out:
# <Axes: >

# %%
df.Price.hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Count plot for the column 'Type'

# %%
sns.countplot(data=df, x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %% [markdown]
# ### Strip plot of columns 'Rating' and 'Type'

# %%
sns.stripplot(y = 'Rating', x='Type', hue='Type', data = df, legend=False)
# Out:
# <Axes: xlabel='Type', ylabel='Rating'>

# %%
df.columns
# Out:
# Index(['Rating', 'Reviews', 'Book_title', 'Description', 'Number_Of_Pages',
#        'Type', 'Price'],
#       dtype='object')

# %% [markdown]
# ### boxplot for the column 'Rating'm

# %%
sns.boxplot(data=df, y='Rating')
# Out:
# <Axes: ylabel='Rating'>

# %% [markdown]
# ### distribution of the column 'Reviews'

# %%
sns.displot(df.Reviews, kind='kde')

# %% [markdown]
# ### plot the heatmap of the correlation matrix of numerical variables

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
corr = df.corr(numeric_only=True)

# Plot the heatmap
plt.figure(figsize = (6, 3))
sns.heatmap(corr, annot = True, cmap = 'coolwarm',            
        fmt = ".1f",            
        xticklabels = corr.columns,            
        yticklabels = corr.columns)
# Out:
# <Axes: >

# %%
plt.scatter(df['Number_Of_Pages'],df['Price'])
plt.show()

# %% [markdown]
# ### Price vs Rating

# %%
plt.scatter(df['Price'],df['Rating'])
plt.show()

# %% [markdown]
# ### pieplot for the column 'Type'

# %%
plt.pie(df['Type'].value_counts(), autopct = '%.1f%%', radius = 1.2, 
        labels=list(df['Type'].value_counts().index))
plt.show()
