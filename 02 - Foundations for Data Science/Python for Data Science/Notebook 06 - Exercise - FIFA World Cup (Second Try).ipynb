# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2.3em;color:#fff;">------------------
#
# <span style="font-family: Arial; font-weight:bold;font-size:2.3em;color:#fff;">------------------
# <span style="font-family: Arial; font-weight:bold;font-size:2.3em;color:#fa9200;">FIFA World Cup

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">Dataset Information:-

# %% [markdown]
# The FIFA World Cup is a global football competition contested by the various football-playing nations of the world. It is contested every four years and is the most prestigious and important trophy in the sport of football.
#
# The FIFA World Cup, often simply called the World Cup, is an international association football competition contested by the senior men's national teams of the members of the Fédération Internationale de Football Association (FIFA), the sport's global governing body. The championship has been awarded every four years since the inaugural tournament in 1930, except in 1942 and 1946 when it was not held because of the Second World War.

# %% [markdown]
# The World Cups dataset shows all information about all the World Cups in history till 2014, while the World Cup Matches dataset shows all the results from the matches contested as part of the cups.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">Problem Statement:-
#
#
#
# A new football club named ‘Brussels United FC’ has just been inaugurated. As a member of this club, you have been assigned a task to carry analysis on matches, players, and world cup data. Here we need to analyze the countries which have won the world cup the most with attendance, goal, and matches per cup based on cities. Also distribution of home and away goals. Whether playing in the home country is a factor for winning or not?
#
# **Steps needs to be followed-**
#
#
# * Total goals scored by year
# * Total matches played and qualified teams by year
# * Matches with the highest number of attendance
# * Cities that hosted highest world cup matches
# * Average attendance by city
# * Teams with the most world cup final victories
# * World cup final results by nation
# * Match outcomes by home and away teams

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">Data Definition:-

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">1. World Cup Matches Dataset
#
# - **Year**: The year in which the match was played
# - **Datetime**: The Date on which the match was played along with a 24 hour format time
# - **Stage**: The stage at which the match was played
# - **Stadium**: Stadium name where the match was held
# - **City**: The city name, where the match was played
# - **Home Team Name**: Home team country name
# - **Home Team Goals**: Total goals scored by the home team by the end of the match
# - **Away Team Goals**: Total goals scored by the away team by the end of the match
# - **Away Team Name**: Away team country name
# - **Win conditions**: Special win condition (if any)
# - **Attendance**: Total crowd present at the stadium
# - **Half-time Home Goals**: Goals scored by the home team until half time
# - **Half-time Away Goals**: Goals scored by the away team until half time
# - **Referee**: Name of the first referee
# - **Assistant 1**: Name of the first assistant referee (linesman)
# - **Assistant 2**: Name of the second assistant referee (linesman)
# - **RoundID**: Unique ID of the Round
# - **MatchID**: Unique ID of the Match
# - **Home Team Initials**: Home team country's three letter initials
# - **Away Team Initials**: Away team country's three left

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">2. World Cup Players Dataset
#
# - **RoundID**: Unique ID of the Round
# - **MatchID**: Unique ID of the Match
# - **Team Initials**: Player's team country's three letter initials
# - **Coach Name**: Player's coach name
# - **Line-up**: Indicates whether the player was in the starting line-up or not
# - **Shirt Number**: Player's shirt number
# - **Player Name**: Player's name
# - **Position**: Position that the player played in
# - **Event**: Important event involving the player (if any)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">3. World Cup Dataset
#
# - **Year**: Year in which the world cup was held
# - **Country**: Country where the world cup was held
# - **Winner**: Team that won the world cup
# - **Runners-Up**: Team that came second
# - **Third**: Team that came third
# - **Fourth**: Team that came fourth
# - **GoalsScored**: Total goals scored in the world cup
# - **QualifiedTeams**: Number of teams that qualified for the world cup
# - **MatchesPlayed**: Total matches played in the world cup
# - **Attendance**: Total attendance in the world cup

# %% [markdown]
# # Solution

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">1. Import libraries </span>

# %%
import numpy as np                  # Scientific Computing
import pandas as pd                 # Data Analysis
import matplotlib.pyplot as plt     # Plotting
import seaborn as sns               # Statistical Data Visualization

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">2. Read the dataset(WorldCupMatches.csv, WorldCupPlayers.csv, WorldCups.csv) </span>
#
# Includes:
#
# - Understanding the Dataset

# %%
df_matches  = pd.read_csv("data/WorldCupMatches.csv")
df_players  = pd.read_csv("data/WorldCupPlayers.csv")
df_cups     = pd.read_csv("data/WorldCups.csv")

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">2.1 Understanding the Dataset</span>

# %%
df_matches.head(3)
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
#
#                   Referee               Assistant 1            Assistant 2  \
# ...

# %%
df_matches.tail(3)
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 4569   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4570   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4571   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 4569              NaN            NaN            NaN         NaN
# 4570              NaN            NaN            NaN         NaN
# 4571              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 4569                   NaN                   NaN     NaN         NaN
# 4570                   NaN                   NaN     NaN         NaN
# 4571                   NaN                   NaN     NaN         NaN
#
#      Assistant 2  RoundID  MatchID Home Team Initials Away Team Initials
# ...

# %%
df_players.head(3)
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'

# %%
df_players.tail(3)
# Out:
#        RoundID    MatchID Team Initials               Coach Name Line-up  \
# 37781   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37782   255959  300186501           GER       LOEW Joachim (GER)       N
# 37783   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
#
#        Shirt Number Player Name Position       Event
# 37781            20      AGUERO      NaN  IH46' Y65'
# 37782            21     MUSTAFI      NaN         NaN
# 37783            23     BASANTA      NaN         NaN

# %%
df_cups.head(3)
# Out:
#    Year  Country   Winner      Runners-Up    Third      Fourth  GoalsScored  \
# 0  1930  Uruguay  Uruguay       Argentina      USA  Yugoslavia           70
# 1  1934    Italy    Italy  Czechoslovakia  Germany     Austria           70
# 2  1938   France    Italy         Hungary   Brazil      Sweden           84
#
#    QualifiedTeams  MatchesPlayed Attendance
# 0              13             18    590.549
# 1              16             17    363.000
# 2              15             18    375.700

# %%
df_cups.tail(3)
# Out:
#     Year       Country   Winner   Runners-Up        Third    Fourth  \
# 17  2006       Germany    Italy       France      Germany  Portugal
# 18  2010  South Africa    Spain  Netherlands      Germany   Uruguay
# 19  2014        Brazil  Germany    Argentina  Netherlands    Brazil
#
#     GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 17          147              32             64  3.359.439
# 18          145              32             64  3.178.856
# 19          171              32             64  3.386.810

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">3. Data Analysis and Preparation</span>

# %% [markdown]
# **Understanding the data set**
#
# Includes:
# - Check dimensions of the dataframe in terms of rows and columns
# - Check data types. Ensure your data types are correct. Refer data definitions to validate
# - Study summary statistics
# - Check for missing values
# - Study correlation
# - Detect outliers

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">3.1 Check dimensions of the dataframe in terms of rows and columns</span>

# %%
# display the dimension
print('Matches:', df_matches.shape)
print('Players:', df_players.shape)
print('Cups   :', df_cups.shape)
# Out:
# Matches: (4572, 20)
# Players: (37784, 9)
# Cups   : (20, 10)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">3.2 Check data types. Ensure your data types are correct. Refer data definitions to validate</span>

# %% [markdown]
# - .info() method
# > *This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage
# - .dtypes
#
# *Note:* If data types are not as per business definition, change the data types as per requirement.

# %% [markdown]
# **Matches**

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
# ...

# %%
df_matches = df_matches.convert_dtypes(convert_string=False, convert_integer=True)
df_matches.Datetime = pd.to_datetime(df_matches.Datetime)
df_matches.RoundID = df_matches.RoundID.astype(object)
df_matches.MatchID = df_matches.MatchID.astype(object)

# %%
df_matches.dtypes
# Out:
# Year                             Int64
# Datetime                datetime64[ns]
# Stage                           object
# Stadium                         object
# City                            object
# Home Team Name                  object
# Home Team Goals                  Int64
# Away Team Goals                  Int64
# Away Team Name                  object
# Win conditions                  object
# Attendance                       Int64
# Half-time Home Goals             Int64
# Half-time Away Goals             Int64
# Referee                         object
# Assistant 1                     object
# Assistant 2                     object
# RoundID                         object
# MatchID                         object
# Home Team Initials              object
# Away Team Initials              object
# dtype: object

# %% [markdown]
# **Players**

# %%
df_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37784 entries, 0 to 37783
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RoundID        37784 non-null  int64
#  1   MatchID        37784 non-null  int64
#  2   Team Initials  37784 non-null  object
#  3   Coach Name     37784 non-null  object
#  4   Line-up        37784 non-null  object
#  5   Shirt Number   37784 non-null  int64
#  6   Player Name    37784 non-null  object
#  7   Position       4143 non-null   object
#  8   Event          9069 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 2.6+ MB

# %%
df_players.RoundID = df_players.RoundID.astype(object)
df_players.MatchID = df_players.MatchID.astype(object)

# %%
df_players.dtypes
# Out:
# RoundID          object
# MatchID          object
# Team Initials    object
# Coach Name       object
# Line-up          object
# Shirt Number      int64
# Player Name      object
# Position         object
# Event            object
# dtype: object

# %% [markdown]
# **Cups**

# %%
df_cups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20 non-null     int64
#  1   Country         20 non-null     object
#  2   Winner          20 non-null     object
#  3   Runners-Up      20 non-null     object
#  4   Third           20 non-null     object
#  5   Fourth          20 non-null     object
#  6   GoalsScored     20 non-null     int64
#  7   QualifiedTeams  20 non-null     int64
#  8   MatchesPlayed   20 non-null     int64
#  9   Attendance      20 non-null     object
# dtypes: int64(4), object(6)
# memory usage: 1.7+ KB

# %%
df_cups.Attendance.head()
# Out:
# 0      590.549
# 1      363.000
# 2      375.700
# 3    1.045.246
# 4      768.607
# Name: Attendance, dtype: object

# %%
df_cups.Attendance = df_cups.Attendance.map(lambda x: x.replace('.',''))
df_cups.Attendance.head()
# Out:
# 0     590549
# 1     363000
# 2     375700
# 3    1045246
# 4     768607
# Name: Attendance, dtype: object

# %%
# df_cups = df_cups.convert_dtypes(convert_string=False, convert_integer=True)
df_cups.Attendance = df_cups.Attendance.astype(int)

# %%
df_cups.dtypes
# Out:
# Year               int64
# Country           object
# Winner            object
# Runners-Up        object
# Third             object
# Fourth            object
# GoalsScored        int64
# QualifiedTeams     int64
# MatchesPlayed      int64
# Attendance         int32
# dtype: object

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">3.3 Study summary statistics<span>

# %%
df_matches.describe(include='all', datetime_is_numeric=True)
# Out:
#                Year                       Datetime        Stage  \
# count         852.0                            852          852
# unique         <NA>                            NaN           23
# top            <NA>                            NaN  Round of 16
# freq           <NA>                            NaN           72
# mean    1985.089202  1985-07-23 04:50:34.154929600          NaN
# min          1930.0            1930-07-13 15:00:00          NaN
# 25%          1970.0            1970-06-07 12:00:00          NaN
# 50%          1990.0            1990-06-14 17:00:00          NaN
# 75%          2002.0            2002-06-22 16:45:00          NaN
# max          2014.0            2014-07-13 16:00:00          NaN
# std       22.448825                            NaN          NaN
#
#                Stadium          City Home Team Name  Home Team Goals  \
# count              852           852            852            852.0
# ...

# %%
df_players.describe(include='all')
# Out:
#            RoundID      MatchID Team Initials                 Coach Name  \
# count      37784.0      37784.0         37784                      37784
# unique       101.0        836.0            82                        335
# top     43950100.0  300186497.0           BRA  SCOLARI Luiz Felipe (BRA)
# freq        2208.0         92.0          2403                        575
# mean           NaN          NaN           NaN                        NaN
# std            NaN          NaN           NaN                        NaN
# min            NaN          NaN           NaN                        NaN
# 25%            NaN          NaN           NaN                        NaN
# 50%            NaN          NaN           NaN                        NaN
# 75%            NaN          NaN           NaN                        NaN
# max            NaN          NaN           NaN                        NaN
#
#        Line-up  Shirt Number Player Name Position  Event
# ...

# %%
df_cups.describe(include='all')
# Out:
#                Year Country  Winner Runners-Up    Third   Fourth  GoalsScored  \
# count     20.000000      20      20         20       20       20    20.000000
# unique          NaN      15       9         10       14       16          NaN
# top             NaN   Italy  Brazil  Argentina  Germany  Uruguay          NaN
# freq            NaN       2       5          3        3        3          NaN
# mean    1974.800000     NaN     NaN        NaN      NaN      NaN   118.950000
# std       25.582889     NaN     NaN        NaN      NaN      NaN    32.972836
# min     1930.000000     NaN     NaN        NaN      NaN      NaN    70.000000
# 25%     1957.000000     NaN     NaN        NaN      NaN      NaN    89.000000
# 50%     1976.000000     NaN     NaN        NaN      NaN      NaN   120.500000
# 75%     1995.000000     NaN     NaN        NaN      NaN      NaN   145.250000
# max     2014.000000     NaN     NaN        NaN      NaN      NaN   171.000000
#
# ...

# %% [markdown]
# * We can see that count of GoalsScored column is 20, mean is 118.95, standard deviation is 32.97.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">3.4 Check for missing values</span>

# %% [markdown]
# **If we encounter with missing data, what we can do:**
#
# * leave as is
# * drop them with dropna()
# * fill missing value with fillna()
# * fill missing values with test statistics like mean
# ----
# * One of the most common problems in data science is missing values.
# * To detect them, there is a beautiful method which is called .isnull(). With this method, we can get a boolean series (True or False).

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;color:#0ab6fa">**Dropping rows with null values**</span>

# %%
df_matches.isnull().sum()
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
df_matches[df_matches.isnull().any(axis=1)].head()
# Out:
#      Year            Datetime        Stage            Stadium           City  \
# 823  2014 2014-06-30 17:00:00  Round of 16  Estadio Beira-Rio  Porto Alegre
# 841  2014 2014-06-30 17:00:00  Round of 16  Estadio Beira-Rio  Porto Alegre
# 852  <NA>                 NaT          NaN                NaN            NaN
# 853  <NA>                 NaT          NaN                NaN            NaN
# 854  <NA>                 NaT          NaN                NaN            NaN
#
#     Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 823        Germany                2                1        Algeria
# 841        Germany                2                1        Algeria
# 852            NaN             <NA>             <NA>            NaN
# 853            NaN             <NA>             <NA>            NaN
# 854            NaN             <NA>             <NA>            NaN
#
#                     Win conditions  Attendance  Half-time Home Goals  \
# ...

# %%
df_matches[df_matches.isnull().sum(axis=1)==20].head()
# Out:
#      Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 852  <NA>      NaT   NaN     NaN  NaN            NaN             <NA>
# 853  <NA>      NaT   NaN     NaN  NaN            NaN             <NA>
# 854  <NA>      NaT   NaN     NaN  NaN            NaN             <NA>
# 855  <NA>      NaT   NaN     NaN  NaN            NaN             <NA>
# 856  <NA>      NaT   NaN     NaN  NaN            NaN             <NA>
#
#      Away Team Goals Away Team Name Win conditions  Attendance  \
# 852             <NA>            NaN            NaN        <NA>
# 853             <NA>            NaN            NaN        <NA>
# 854             <NA>            NaN            NaN        <NA>
# 855             <NA>            NaN            NaN        <NA>
# 856             <NA>            NaN            NaN        <NA>
#
#      Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 852                  <NA>                  <NA>     NaN         NaN
# ...

# %%
df_matches.drop(index=df_matches[df_matches.isnull().sum(axis=1)==20].index, inplace=True)

# %%
df_matches[df_matches.isnull().any(axis=1)].head()
# Out:
#      Year            Datetime        Stage            Stadium           City  \
# 823  2014 2014-06-30 17:00:00  Round of 16  Estadio Beira-Rio  Porto Alegre
# 841  2014 2014-06-30 17:00:00  Round of 16  Estadio Beira-Rio  Porto Alegre
#
#     Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 823        Germany                2                1        Algeria
# 841        Germany                2                1        Algeria
#
#                     Win conditions  Attendance  Half-time Home Goals  \
# 823  Germany win after extra time         <NA>                     0
# 841  Germany win after extra time         <NA>                     0
#
#      Half-time Away Goals             Referee                Assistant 1  \
# 823                     0  RICCI Sandro (BRA)  DE CARVALHO Emerson (BRA)
# 841                     0  RICCI Sandro (BRA)  DE CARVALHO Emerson (BRA)
#
#                  Assistant 2 RoundID    MatchID Home Team Initials  \
# ...

# %%
df_matches.isna().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              2
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;color:#0ab6fa">Mean and Median imputation for Matches dataset</span>

# %% [markdown]
# **For numerical variables we use mean/ median**
#
# * Mean as a measure is greatly affected by outliers or if the distribution of the data or column is not normally-distributed. Therefore, it’s wise to first check the distribution of the column before deciding if to use a mean imputation or median imputation
#
# * Mean imputation works better if the distribution is normally-distributed or has a Gaussian distribution, while median imputation is preferable for skewed distribution(be it right or left)
#
# > Sometimes it is advisable to drop the columns when the NULL values are significantly more than the other values present.

# %%
df_melt = df_matches.select_dtypes(include=['number']).fillna(0).melt()
df_melt = df_melt[df_melt.variable != 'Year']
df_melt.dtypes
# Out:
# variable    object
# value       object
# dtype: object

# %%
df_melt.value = df_melt.value.astype(int)
df_melt.dtypes
# Out:
# variable    object
# value        int32
# dtype: object

# %%
def central_tendency(x, **kwargs):
    ax = plt.gca()
    mean = x.mean()
    ax.axvline(mean, c='k', ls='--', lw=2.5)
    ax.set_title('{}\nMean: {:,.2f}'.format(ax.get_title(), mean))
    
sns.set(font_scale=1.5) 
g = sns.displot(data=df_melt, 
                x="value", hue="variable", col="variable", legend=False, common_norm=False, 
                kind="kde", facet_kws={'sharex': False, 'sharey': False})
g.map(central_tendency, 'value')
plt.show()

# %%
df_matches[df_matches.isnull().any(axis=1)].head()
# Out:
#      Year            Datetime        Stage            Stadium           City  \
# 823  2014 2014-06-30 17:00:00  Round of 16  Estadio Beira-Rio  Porto Alegre
# 841  2014 2014-06-30 17:00:00  Round of 16  Estadio Beira-Rio  Porto Alegre
#
#     Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 823        Germany                2                1        Algeria
# 841        Germany                2                1        Algeria
#
#                     Win conditions  Attendance  Half-time Home Goals  \
# 823  Germany win after extra time         <NA>                     0
# 841  Germany win after extra time         <NA>                     0
#
#      Half-time Away Goals             Referee                Assistant 1  \
# 823                     0  RICCI Sandro (BRA)  DE CARVALHO Emerson (BRA)
# 841                     0  RICCI Sandro (BRA)  DE CARVALHO Emerson (BRA)
#
#                  Assistant 2 RoundID    MatchID Home Team Initials  \
# ...

# %%
df_matches.loc[822:842, ['Year','City','Datetime', 'Attendance']]
# Out:
#      Year             City            Datetime  Attendance
# 822  2014        Brasilia  2014-06-30 13:00:00       67882
# 823  2014    Porto Alegre  2014-06-30 17:00:00        <NA>
# 824  2014       Fortaleza  2014-07-04 17:00:00       60342
# 825  2014  Rio De Janeiro  2014-07-04 13:00:00       74240
# 826  2014  Belo Horizonte  2014-07-08 17:00:00       58141
# 827  2014        Brasilia  2014-07-12 17:00:00       68034
# 828  2014  Rio De Janeiro  2014-07-13 16:00:00       74738
# 829  2014       Sao Paulo  2014-07-09 17:00:00       63267
# 830  2014        Salvador  2014-07-05 17:00:00       51179
# 831  2014        Brasilia  2014-07-05 13:00:00       68551
# 832  2014       Fortaleza  2014-06-29 13:00:00       58817
# 833  2014          Recife  2014-06-29 17:00:00       41242
# 834  2014       Sao Paulo  2014-07-01 13:00:00       63255
# 835  2014        Salvador  2014-07-01 17:00:00       51227
# 836  2014  Belo Horizonte  2014-06-28 13:00:00       57714
# ...

# %%
df_matches.groupby(['Year', 'City'])['Attendance'].mean()
# Out:
# Year  City
# 1930  Montevideo         32808.277778
# 1934  Bologna                 18500.0
#       Florence           28666.666667
#       Genoa                   21000.0
#       Milan              23666.666667
#                              ...
# 2014  Porto Alegre            42976.5
#       Recife             41020.666667
#       Rio De Janeiro          74197.1
#       Salvador                50385.0
#       Sao Paulo             62764.375
# Name: Attendance, Length: 180, dtype: Float64

# %%
# # Interpolate = > Takes the previous and the next one to gives the mean of this 2 values
# s = df_matches.Attendance.copy().astype(float)
# s.interpolate().loc[822:842]

# # Taking the previous value
# df_matches.Attendance.fillna(method='ffill').loc[822:842]

# Taking the attendance avg by year
df_matches.Attendance = df_matches.groupby(['Year', 'City'])['Attendance'].transform(lambda x: x.fillna(int(x.mean())))
df_matches.Attendance.loc[822:842]
# Out:
# 822    67882
# 823    42976
# 824    60342
# 825    74240
# 826    58141
# 827    68034
# 828    74738
# 829    63267
# 830    51179
# 831    68551
# 832    58817
# 833    41242
# 834    63255
# 835    51227
# 836    57714
# 837    73804
# 838    58817
# 839    41242
# 840    67882
# 841    42976
# 842    63255
# Name: Attendance, dtype: Int64

# %%
df_melt = df_matches.select_dtypes(include=['number']).melt()
df_melt = df_melt[df_melt.variable != 'Year']
df_melt.value = df_melt.value.astype(int)

sns.set(font_scale=1.5) 
g = sns.displot(data=df_melt, 
                x="value", hue="variable", col="variable", legend=False, common_norm=False, 
                kind="kde", facet_kws={'sharex': False, 'sharey': False})
g.map(central_tendency, 'value')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;color:#0ab6fa">Mode imputation for "Position" and "Event"</span>

# %%
df_players.isnull().sum()
# Out:
# RoundID              0
# MatchID              0
# Team Initials        0
# Coach Name           0
# Line-up              0
# Shirt Number         0
# Player Name          0
# Position         33641
# Event            28715
# dtype: int64

# %%
df_players.isnull().sum()/len(df_players) * 100
# Out:
# RoundID           0.000000
# MatchID           0.000000
# Team Initials     0.000000
# Coach Name        0.000000
# Line-up           0.000000
# Shirt Number      0.000000
# Player Name       0.000000
# Position         89.035041
# Event            75.997777
# dtype: float64

# %% [markdown]
# * Mode imputation means replacing missing values by the mode, or the most frequent- category value.

# %%
df_players.Position.value_counts()
# Out:
# GK     2441
# C      1510
# GKC     192
# Name: Position, dtype: int64

# %%
df_players.Position.mode()[0]
# Out:
# 'GK'

# %%
df_players.Position.fillna(df_players.Position.mode()[0], inplace=True)

# %%
df_players.Position.isnull().sum()
# Out:
# 0

# %%
df_players.Event.value_counts()
# Out:
# OH46'              247
# IH46'              206
# Y1'                 87
# I77'                78
# I78'                78
#                   ...
# Y58' G59' G81'       1
# P4'                  1
# Y1' Y49' RSY49'      1
# G18' G84'            1
# G60' O83'            1
# Name: Event, Length: 1893, dtype: int64

# %%
df_players.Event.fillna(df_players.Event.mode()[0], inplace=True)

# %%
df_players.Position.isnull().sum()
# Out:
# 0

# %%
df_cups.isnull().sum()
# Out:
# Year              0
# Country           0
# Winner            0
# Runners-Up        0
# Third             0
# Fourth            0
# GoalsScored       0
# QualifiedTeams    0
# MatchesPlayed     0
# Attendance        0
# dtype: int64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">3.5 Study correlation</span>

# %%
corr = df_matches.corr(numeric_only=True)

mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

sns.set(font_scale=0.75)
plt.figure(figsize = (5, 3))
sns.heatmap(corr, annot=True, mask=mask, cmap='YlGn')
plt.title('Matches')
plt.show()

# %%
df_players.dtypes
# Out:
# RoundID          object
# MatchID          object
# Team Initials    object
# Coach Name       object
# Line-up          object
# Shirt Number      int64
# Player Name      object
# Position         object
# Event            object
# dtype: object

# %%
corr = df_cups.corr(numeric_only=True)

mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

sns.set(font_scale=0.75)
plt.figure(figsize = (5, 3))
sns.heatmap(corr, annot=True, mask=mask, cmap='YlGn')
plt.title('Players')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">3.6 Detect outliers</span>

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;color:#0ab6fa">**MATCHES**</span>

# %%
df_matches['Total Goals'] = df_matches['Home Team Goals'] + df_matches['Away Team Goals']

sns.set()
df_matches.plot(kind='box', subplots=True, sharey=False, fontsize=6, figsize=(12, 3))
plt.subplots_adjust(wspace=0.5) 
plt.show()

# %%
# How are the home goal pear each away goal?
# fig = plt.figure(figsize=(6,3))
sns.set(font_scale=0.75)
df_matches.boxplot(column='Home Team Goals', by = 'Away Team Goals', figsize = (7, 3))
plt.subplots_adjust(top=0.85)
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.set(font_scale=1)
sns.boxplot(y=df_matches["Total Goals"],
            x=df_matches["Year"])
plt.grid(True)
plt.title("Total goals scored during game by year", color='b')
plt.show()

# %%
# Getting IQR to remove outliers
df_matches_IQR = df_matches.select_dtypes(include=np.number)

Q1 = df_matches_IQR.quantile(0.25, numeric_only=True)
Q3 = df_matches_IQR.quantile(0.75, numeric_only=True)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year                       32.0
# Home Team Goals             2.0
# Away Team Goals             2.0
# Attendance              31361.5
# Half-time Home Goals        1.0
# Half-time Away Goals        1.0
# Total Goals                 3.0
# dtype: Float64

# %%
df_matches_IQR = df_matches_IQR[~((df_matches_IQR < (Q1 - 1.5 * IQR)) |(df_matches_IQR > (Q3 + 1.5 * IQR))).any(axis=1)]

sns.set(font_scale=0.75)
df_matches_IQR.boxplot(column='Home Team Goals', by = 'Away Team Goals', figsize = (7, 3))
plt.subplots_adjust(top=0.85)
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.set(font_scale=1)
sns.boxplot(y=df_matches_IQR["Total Goals"],
            x=df_matches_IQR["Year"])
plt.grid(True)
plt.title("Total goals scored during game by year", color='b')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;color:#0ab6fa">**PLAYERS**</span>

# %%
sns.set()
df_players.plot(kind='box', subplots=True, sharey=False, fontsize=6, figsize=(12, 3))
plt.subplots_adjust(wspace=0.5) 
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;color:#0ab6fa">**CUPS**</span>

# %%
sns.set()
df_cups.plot(kind='box', subplots=True, sharey=False, fontsize=6, figsize=(12, 3))
plt.subplots_adjust(wspace=0.5) 
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">4. Variate analysis</span>

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">4.1 Univariate analysis</span>

# %%
df_melt = df_matches_IQR.select_dtypes(include=['number']).melt()
df_melt = df_melt[df_melt.variable != 'Year']
df_melt.value = df_melt.value.astype(int)

# %%
sns.set(font_scale=1.5) 

g = sns.displot(data=df_melt, 
                x="value", hue="variable", col="variable", legend=False, common_norm=False, 
                kind="kde", facet_kws={'sharex': False, 'sharey': False})
g.map(central_tendency, 'value')
plt.show()

# %%
# Migration of distplot
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# https://seaborn.pydata.org/generated/seaborn.FacetGrid.html
sns.set(font_scale=1) 

g = sns.FacetGrid(data=df_melt, col='variable', sharex= False, sharey=False)
g.map_dataframe(sns.histplot, x="value", 
                kde=True, stat="density", common_bins=False, kde_kws=dict(cut=3))
g.map(central_tendency, 'value')
plt.subplots_adjust(top=.8) 
plt.tight_layout()
plt.show()

# %%
sns.set()
plt.figure(figsize = (5, 3))
sns.histplot(df_cups.Year, kde=True, stat="density", kde_kws=dict(cut=3))
plt.show()

# %%
plt.figure(figsize=(13, 4))
sns.countplot(x=df_cups.Country.fillna('Missing'), order = df_cups.Country.value_counts().index)
_ = plt.xticks(rotation=90)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">4.2 Bivariate Analysis</span>

# %%
from scipy.stats import pearsonr

def corrfunc(x, y, **kws):
    (r, p) = pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r={:.2f}, {}".format(r, 'p < 0.001' if p<=0.001 else 'p > 0.001'), xy=(.1, .9), xycoords=ax.transAxes)
    
sns.set(font_scale=1) 
graph = sns.pairplot(data=df_matches_IQR.astype(float), diag_kind="kde", corner=True)
graph.map_lower(corrfunc)
plt.show()
sns.set()

# %%
sns.set(font_scale=1) 
graph = sns.pairplot(data=df_cups, diag_kind="kde", corner=True)
graph.map_lower(corrfunc)
plt.show()
sns.set()

# %%
df_cups.plot(kind='scatter', x='Year', y="GoalsScored",alpha = .8,color = 'blue',figsize= (6,6))
plt.xlabel('Year')             
plt.ylabel("GoalsScored")
plt.title('Scatter Plot') 
plt.show()

# %% [markdown]
# * Now, it is easier to see the fact that although Year and GoalsScored variables are positively correlated, there is a negative correlation between Year and AverageGoal.
#
# * This contradiction shows us that as the years passed, teams have not began to score more goals in a single match.
#
# * Now it is easier to understand why GoalsScored has been increasing from 1930 so far. Let's prepare a line plot for different variables.

# %%
df_cups["AverageGoal"] = df_cups.GoalsScored/df_cups.MatchesPlayed

# %%
ax = plt.gca()

df_cups.plot(kind='line', x = "Year", y = "GoalsScored", color = "green", ax=ax,grid = True,figsize = (7,7))
df_cups.plot(kind='line', x = "Year", y = "MatchesPlayed", color = 'red', ax=ax,grid = True)
df_cups.plot(kind='line', x = "Year", y = "QualifiedTeams", color = 'b', ax=ax,grid = True)
df_cups.plot(kind='line', x = "Year", y = "AverageGoal", color = 'goldenrod', ax=ax,grid = True)
plt.legend(loc = "upper left")
plt.show()

# %%
df_cups_log = df_cups.copy()
df_cups_log["GoalsScored"] = np.log1p(df_cups["GoalsScored"])
df_cups_log["MatchesPlayed"] = np.log1p(df_cups["MatchesPlayed"])
df_cups_log["QualifiedTeams"] = np.log1p(df_cups["QualifiedTeams"])
df_cups_log["AverageGoal"] = np.log1p(df_cups["AverageGoal"])

ax = plt.gca()

df_cups_log.plot(kind='line', x = "Year", y = "GoalsScored", color = "green", ax=ax,grid = True,figsize = (7,7))
df_cups_log.plot(kind='line', x = "Year", y = "MatchesPlayed", color = 'red', ax=ax,grid = True)
df_cups_log.plot(kind='line', x = "Year", y = "QualifiedTeams", color = 'b', ax=ax,grid = True)
df_cups_log.plot(kind='line', x = "Year", y = "AverageGoal", color = 'goldenrod', ax=ax,grid = True)
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">4.3 Multivariate plotting</span>

# %%
_ = sns.lmplot(x='Year', y='GoalsScored', hue='Country', 
               # data=df_cups.loc[df_cups['Country'].isin(['Uruguay', 'Italy', 'France', 'Brazil', 'Switzerland', 
               #                                           'Chile', 'England', 'Mexico', 'Germany', 'Argentina', 
               #                                           'Spain', 'Mexico'])], 
               data=df_cups,
               fit_reg=False)

# %%
f,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df_cups.corr(numeric_only=True), annot=True, linewidths=.5, fmt= '.4f', ax=ax, cmap='coolwarm')
plt.show()

# %%
df_matches.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials',
#        'Total Goals'],
#       dtype='object')

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">5. Lets come to the problem statement:

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">5.1 Total goals scored by year

# %%
plt.figure(figsize=(13,7))
ax = plt.scatter("Year", "GoalsScored", data=df_cups,
            c=df_cups["GoalsScored"], cmap="inferno",
            s=900, alpha=.7, linewidth=2, edgecolor="k")

plt.xticks(df_cups["Year"].unique())
plt.yticks(np.arange(60,200,20))
plt.title('Total goals scored by year',color='b')
plt.xlabel("year")
plt.ylabel("total goals scored")
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">5.2 Total matches played and qualified teams by year

# %% [markdown]
# * In the tournaments between 1934 and 1978, 16 teams competed in each tournament, except in 1938, when Austria was absorbed into Germany after qualifying, leaving the tournament with 15 teams, and in 1950, when India, Scotland, and Turkey withdrew, leaving the tournament with 13 teams
# * The tournament was expanded to 24 teams in 1982, and then to 32 in 1998,also allowing more teams from Africa, Asia and North America to take part.

# %%
plt.figure(figsize=(12,7))

sns.barplot(x=df_cups["Year"], y=df_cups["MatchesPlayed"], linewidth=1,
            edgecolor=["k" for c in range(len(df_cups))], color="b", label="Total matches played")

sns.barplot(x=df_cups["Year"], y=df_cups["QualifiedTeams"], linewidth=1,
            edgecolor=[c for c in "k"*len(df_cups)], color="r", label="Total qualified teams")

plt.legend(loc="best",prop={"size":13})
plt.title("Qualified teams by year",color='b')
plt.grid(True)
plt.ylabel("total matches and qualified teams by year")
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">5.3.Matches with highest number of attendance

# %%
# Highest attendance matches ever
df_matches_highest = df_matches.sort_values(by='Attendance', ascending=False)[:10]
df_matches_highest['Stadium'].unique()
# Out:
# array(['Maracan� - Est�dio Jornalista M�rio Filho', 'Estadio Azteca'],
#       dtype=object)

# %%
df_matches_highest['Stadium'] = df_matches_highest["Stadium"].replace(
                                    'Maracan� - Est�dio Jornalista M�rio Filho',"Maracanã Stadium")

# %%
df_matches_highest['Game'] = df_matches_highest["Home Team Name"] + " .Vs. " + df_matches_highest["Away Team Name"]
df_matches_highest['Date'] = df_matches_highest["Datetime"].dt.strftime('%Y-%m-%d')

# %%
import matplotlib as mpl

plt.figure(figsize=(10,9))
ax = sns.barplot(y=df_matches_highest["Game"], x = df_matches_highest["Attendance"],
                 palette="gist_ncar", linewidth = 1, edgecolor=[c for c in "k"*len(df_matches_highest)])
ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.ylabel("Match Teams")
plt.xlabel("Attendance")
plt.title("Matches with highest number of attendace",color='b')

for i,j in enumerate(" Stadium: "+df_matches_highest["Stadium"]+", Date: " + df_matches_highest["Date"]):
    ax.text(.7, i, j, fontsize = 12, color="white", weight = "bold")

plt.show()

# %%
# Highest attendance matches per year
import matplotlib as mpl

# Preparing the data to plot
df_hmpy = df_matches.iloc[df_matches.groupby('Year').Attendance.idxmax()].copy()
df_hmpy['Stadium'] = df_hmpy["Stadium"].replace('Maracan� - Est�dio Jornalista M�rio Filho',"Maracanã Stadium")
df_hmpy['Away Team Name'] = df_hmpy['Away Team Name'].replace('rn">Bosnia and Herzegovina', 'Bosnia')
df_hmpy['Game'] = df_hmpy["Home Team Name"] + " .Vs. " + df_hmpy["Away Team Name"]

# Plotting

plt.figure(figsize=(10,9))
ax = sns.barplot(y=df_hmpy["Year"].astype('string'), x = df_hmpy["Attendance"],
                 palette="gist_ncar", linewidth = 1, edgecolor=[c for c in "k"*len(df_hmpy)])
ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
# plt.axvline(x=df_matches_highest.Attendance.min())
plt.ylabel("Year")
plt.xlabel("Attendance")
plt.title("Matches with highest number of attendace per Year",color='b')
for i, j in enumerate(df_hmpy["Game"]):
    ax.text(1000, i, j, fontsize = 10, color="white", weight = "bold")

plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">5.4 Cities that hosted highest world cup matches

# %%
# Cities with the greater hosted matches
df_mat_c = df_matches["City"].value_counts().reset_index()[:10]

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(y=df_mat_c["index"], x=df_mat_c["City"], palette="plasma",
                 linewidth=1, edgecolor=[c for c in "k"*len(df_mat_c)])
plt.xlabel("Number of matches")
plt.ylabel("City")
plt.title("Cities with maximum world cup matches",color='b')
for i,j in enumerate("Matches: " + df_mat_c["City"].astype(str)):
    ax.text(.7, i, j,fontsize = 13,color="w")
plt.show()

# %%
# Cities per year with the greater hosted matches
df_mcy = df_matches.groupby(['Year','City']).MatchID.count().reset_index()
df_mcy = df_mcy.iloc[df_mcy.groupby(['Year'])['MatchID'].idxmax()]
df_mcy['City'] = df_mcy["City"].replace('D�Sseldorf ',"Düsseldorf")

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(y=df_mcy["Year"].astype(str), x=df_mcy["MatchID"], palette="plasma",
                 linewidth=1, edgecolor=[c for c in "k"*len(df_mcy)])
plt.xlabel("Number of matches")
plt.ylabel("Year")
plt.title("Cities per Year with maximum world cup matches",color='b')
for i,j in enumerate(df_mcy["City"] + ", " + df_mcy["MatchID"].astype(str) + ' matches.'):
    ax.text(.1, i, j, fontsize = 8, color="w")
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">5.5.Average attendance by city

# %%
# Top 10 Cities with the highest average attendance
df_ct_at = df_matches.groupby("City")["Attendance"].mean().reset_index()
df_ct_at = df_ct_at.sort_values(by="Attendance",ascending=False)[:10]

# %%
import matplotlib as mpl

plt.figure(figsize=(10,10))

ax = sns.barplot(x="Attendance", y="City",
            data=df_ct_at,
            linewidth = 1,
            edgecolor = [c for c in "k"*len(df_ct_at)],
            palette  = "Spectral_r")
ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
for i,j in enumerate("Average attendance: " + np.around(df_ct_at["Attendance"],0).astype(str)):
    ax.text(1000,i,j,fontsize=12)
plt.grid(True)

plt.title("Average attendance by city",color='b')
plt.show()

# %%
# City with the highest average attendance per year
import matplotlib as mpl

# Preparing the data to plot
df_hmpy = df_matches.groupby(['Year','City']).Attendance.mean().reset_index()
df_hmpy = df_hmpy.iloc[df_hmpy.groupby(['Year'])['Attendance'].idxmax()]

# %%
# City with the highest average attendance per year
import matplotlib as mpl

# Preparing the data to plot
df_hmpy = df_matches.groupby(['Year','City']).Attendance.mean().reset_index()
df_hmpy = df_hmpy.iloc[df_hmpy.groupby(['Year'])['Attendance'].idxmax()]

# Plotting
plt.figure(figsize=(10,9))
ax = sns.barplot(y=df_hmpy["Year"].astype('string'), x = df_hmpy["Attendance"],
                 palette="Spectral_r", linewidth = 1, edgecolor=[c for c in "k"*len(df_hmpy)])
ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.ylabel("Year")
plt.xlabel("Attendance")
plt.title("City with the Highest Average Attendance per Year",color='b')
for i, j in enumerate("City " + df_hmpy['City'] + ", Avg: " + np.around(df_hmpy["Attendance"],0).astype(str)):
    ax.text(1000, i, j, fontsize = 10, weight = "bold")
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">5.6.Teams with the most world cup final victories

# %% [markdown]
# * The 20 World Cup tournaments have been won by eight national teams. Brazil have won five times, and they are the only team to have played in every tournament. The other World Cup winners are Germany and Italy, with four titles each; Argentina and inaugural winner Uruguay, with two titles each; and England, France, and Spain, with one title each.

# %%
from copy import deepcopy 

df_cupswin = deepcopy(df_cups)
df_cupswin["Winner"] = df_cupswin["Winner"].replace("Germany FR","Germany")
df_cupswin["Runners-Up"] = df_cupswin["Runners-Up"].replace("Germany FR","Germany")
df_cupswin["Third"] = df_cupswin["Third"].replace("Germany FR","Germany")
df_cupswin["Fourth"] = df_cupswin["Fourth"].replace("Germany FR","Germany")

df_cupsummary = pd.melt(df_cupswin, id_vars=['Year'], value_vars=['Winner', 'Runners-Up', 'Third', 'Fourth'],
                        var_name='Classification', value_name='Team')
df_cupsummary = pd.crosstab(df_cupsummary.Team, df_cupsummary.Classification)
df_cupsummary['Total'] = df_cupsummary.Fourth + df_cupsummary['Runners-Up'] + df_cupsummary.Third + df_cupsummary.Winner
df_cupsummary = df_cupsummary[['Winner', 'Runners-Up', 'Third', 'Fourth', 'Total']]
df_cupsummary.sort_values('Winner', ascending=False)
# Out:
# Classification  Winner  Runners-Up  Third  Fourth  Total
# Team
# Brazil               5           2      2       2     11
# Italy                4           2      1       1      8
# Germany              4           4      4       1     13
# Uruguay              2           0      0       3      5
# Argentina            2           3      0       0      5
# England              1           0      0       1      2
# France               1           1      2       1      5
# Spain                1           0      0       1      2
# Chile                0           0      1       0      1
# Portugal             0           0      1       1      2
# Belgium              0           0      0       1      1
# USA                  0           0      1       0      1
# Turkey               0           0      1       0      1
# Sweden               0           1      2       1      4
# Soviet Union         0           0      0       1      1
# ...

# %%
df_cupswin['Year'] = df_cupswin.Year.astype(str)

c1 = df_cupswin.groupby("Winner")["Year"].apply(" , ".join).reset_index()
c2 = df_cupswin.groupby("Winner")["Year"].count().reset_index()
df_totalcups = (c1.merge(c2, left_on="Winner", right_on="Winner", how="left"))
df_totalcups.columns = ['Winner', 'Years', 'Cups']
df_totalcups = df_totalcups.sort_values(by="Cups", ascending=False)
df_totalcups
# Out:
#       Winner                             Years  Cups
# 1     Brazil  1958 , 1962 , 1970 , 1994 , 2002     5
# 4    Germany         1954 , 1974 , 1990 , 2014     4
# 5      Italy         1934 , 1938 , 1982 , 2006     4
# 0  Argentina                       1978 , 1986     2
# 7    Uruguay                       1930 , 1950     2
# 2    England                              1966     1
# 3     France                              1998     1
# 6      Spain                              2010     1

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x="Cups", y="Winner", data=df_totalcups,
            palette="jet_r", alpha=.8, linewidth=2, edgecolor=[c for c in "k"*len(df_totalcups)])
for i,j in enumerate("Years : " + df_totalcups["Years"]):
    ax.text(.1, i, j, weight="bold")

plt.title("Teams with the most world cup final victories")
plt.grid(True)
plt.xlabel("count")
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">5.7.World cup final results by nation

# %%
df_cupsummary
# Out:
# Classification  Winner  Runners-Up  Third  Fourth  Total
# Team
# Argentina            2           3      0       0      5
# Austria              0           0      1       1      2
# Belgium              0           0      0       1      1
# Brazil               5           2      2       2     11
# Bulgaria             0           0      0       1      1
# Chile                0           0      1       0      1
# Croatia              0           0      1       0      1
# Czechoslovakia       0           2      0       0      2
# England              1           0      0       1      2
# France               1           1      2       1      5
# Germany              4           4      4       1     13
# Hungary              0           2      0       0      2
# Italy                4           2      1       1      8
# Korea Republic       0           0      0       1      1
# Netherlands          0           3      1       1      5
# ...

# %%
df_cupsmelt = pd.melt(df_cupsummary.reset_index(), 
                      id_vars=['Team'], value_vars=['Winner', 'Runners-Up', 'Third', 'Fourth'],
                      var_name='Classification', value_name='Count')
df_cupsmelt.drop(df_cupsmelt[df_cupsmelt.Count==0].index, inplace=True)
df_cupsmelt.head()
# Out:
#          Team Classification  Count
# 0   Argentina         Winner      2
# 3      Brazil         Winner      5
# 8     England         Winner      1
# 9      France         Winner      1
# 10    Germany         Winner      4

# %%
plt.figure(figsize=(8,15))
sns.barplot(x="Count", y="Team", data=df_cupsmelt, hue="Classification",
            palette=["goldenrod", "silver", "rosybrown", "turquoise"], linewidth=1,edgecolor=[c for c in "k"*len(df_cupsmelt)])
plt.legend(loc="center right", prop={"size":10})
plt.title("Final results by nation", color='b')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">5.8.Match outcomes by home and away teams

# %%
def label(matches):
    if matches["Home Team Goals"] > matches["Away Team Goals"]:  return "Home team win"
    if matches["Away Team Goals"] > matches["Home Team Goals"]:  return "Away team win"
    if matches["Home Team Goals"] == matches["Away Team Goals"]: return "Draw. No Winner"

df_matches["outcome"] = df_matches.apply(lambda x: label(x), axis=1)
df_matches["outcome"]
# Out:
# 0        Home team win
# 1        Home team win
# 2        Home team win
# 3        Home team win
# 4        Home team win
#             ...
# 847    Draw. No Winner
# 848      Away team win
# 849    Draw. No Winner
# 850      Away team win
# 851      Home team win
# Name: outcome, Length: 852, dtype: object

# %%
plt.figure(figsize=(5,5))
df_matches["outcome"].value_counts().plot.pie(autopct="%1.0f%%", fontsize =14, 
                                              colors = sns.color_palette("husl"),
                                              wedgeprops={"linewidth":2,"edgecolor":"white"},
                                              shadow=True, label="")
circ = plt.Circle((0,0),.7,color="white")
plt.gca().add_artist(circ)
plt.title("Match outcomes by home and away teams", color='b')
plt.show()

# %% [markdown]
# **End**
