# %% [markdown]
# # Colorlover

# %% [markdown]
# To install the package, run the below command in a Jupyter notebook and once the command runs successfully, restart the kernel.

# %%
# !pip install colorlover

# %% [markdown]
# To import the package, run the following command in a Jupyter notebook

# %%
import colorlover as cl

# %% [markdown]
# # Documentacion
#
# - [colorlover](https://github.com/plotly/colorlover#docs)

# %%
import colorlover as cl
from IPython.display import HTML

HTML(cl.to_html( cl.flipper()['seq']['3'] ))
# Out:
# <div style="display:inline-block;padding:10px;"><div>Blues</div><div style="background-color:rgb(222,235,247);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(158,202,225);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(49,130,189);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div></div><div style="display:inline-block;padding:10px;"><div>BuGn</div><div style="background-color:rgb(229,245,249);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(153,216,201);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(44,162,95);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div></div><div style="display:inline-block;padding:10px;"><div>BuPu</div><div style="background-color:rgb(224,236,244);height:20px;width:20px;margin-bottom:0px;display:inline-b
# ...

# %%
cl.flipper()['seq']['3']
# Out:
# {'Blues': ['rgb(222,235,247)', 'rgb(158,202,225)', 'rgb(49,130,189)'],
#  'BuGn': ['rgb(229,245,249)', 'rgb(153,216,201)', 'rgb(44,162,95)'],
#  'BuPu': ['rgb(224,236,244)', 'rgb(158,188,218)', 'rgb(136,86,167)'],
#  'GnBu': ['rgb(224,243,219)', 'rgb(168,221,181)', 'rgb(67,162,202)'],
#  'Greens': ['rgb(229,245,224)', 'rgb(161,217,155)', 'rgb(49,163,84)'],
#  'Greys': ['rgb(240,240,240)', 'rgb(189,189,189)', 'rgb(99,99,99)'],
#  'OrRd': ['rgb(254,232,200)', 'rgb(253,187,132)', 'rgb(227,74,51)'],
#  'Oranges': ['rgb(254,230,206)', 'rgb(253,174,107)', 'rgb(230,85,13)'],
#  'PuBu': ['rgb(236,231,242)', 'rgb(166,189,219)', 'rgb(43,140,190)'],
#  'PuBuGn': ['rgb(236,226,240)', 'rgb(166,189,219)', 'rgb(28,144,153)'],
#  'PuRd': ['rgb(231,225,239)', 'rgb(201,148,199)', 'rgb(221,28,119)'],
#  'Purples': ['rgb(239,237,245)', 'rgb(188,189,220)', 'rgb(117,107,177)'],
#  'RdPu': ['rgb(253,224,221)', 'rgb(250,159,181)', 'rgb(197,27,138)'],
# ...

# %% [markdown]
# ### cl.scales
#
# All of the color scales in colorlover

# %%
import colorlover as cl

cl.scales['3']['div']['RdYlBu']
# Out:
# ['rgb(252,141,89)', 'rgb(255,255,191)', 'rgb(145,191,219)']

# %%
HTML(cl.to_html( {'RdYlBu 3 steps': cl.scales['3']['div']['RdYlBu']} ))
# Out:
# <div style="display:inline-block;padding:10px;"><div>RdYlBu 3 steps</div><div style="background-color:rgb(252,141,89);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(255,255,191);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(145,191,219);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div></div>

# %% [markdown]
# ### cl.to_numeric( scale )
#
# Converts scale of RGB or HSL strings to list of tuples with RGB integer values

# %%
cl.to_numeric( cl.scales['3']['div']['RdYlBu'] )
# Out:
# [(252.0, 141.0, 89.0), (255.0, 255.0, 191.0), (145.0, 191.0, 219.0)]

# %%
HTML(cl.to_html( {'RdYlBu 3 steps': cl.to_numeric( cl.scales['3']['div']['RdYlBu'] )} ))
# Out:
# <div style="display:inline-block;padding:10px;"><div>RdYlBu 3 steps</div><div style="background-color:rgb(252.0, 141.0, 89.0);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(255.0, 255.0, 191.0);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(145.0, 191.0, 219.0);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div></div>

# %% [markdown]
# ### cl.to_hsl( scale )
#
# Converts a string RGB or numeric RGB colorscale to HSL

# %%
cl.to_hsl( cl.scales['3']['div']['RdYlBu'] )
# Out:
# ['hsl(19, 96%, 67%)', 'hsl(60, 100%, 87%)', 'hsl(203, 51%, 71%)']

# %%
HTML(cl.to_html( {'RdYlBu 3 steps': cl.to_hsl( cl.scales['3']['div']['RdYlBu'])} ))
# Out:
# <div style="display:inline-block;padding:10px;"><div>RdYlBu 3 steps</div><div style="background-color:hsl(19, 96%, 67%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(60, 100%, 87%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(203, 51%, 71%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div></div>

# %% [markdown]
# ### cl.to_rgb( scale )
#
# Convert an HSL or numeric RGB color scale to string RGB color scale

# %%
cl.to_rgb( cl.scales['3']['div']['RdYlBu'] )
# Out:
# ['rgb(252,141,89)', 'rgb(255,255,191)', 'rgb(145,191,219)']

# %%
HTML(cl.to_html( {'RdYlBu 3 steps': cl.to_rgb( cl.scales['3']['div']['RdYlBu'] )} ))
# Out:
# <div style="display:inline-block;padding:10px;"><div>RdYlBu 3 steps</div><div style="background-color:rgb(252,141,89);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(255,255,191);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(145,191,219);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div></div>

# %% [markdown]
# ### cl.to_html( scale )
#
# Traverse color scale dictionary and return available color scales as HTML string

# %%
cl.to_html( cl.scales['3']['div']['RdYlBu'] )
# Out:
# '<div style="background-color:rgb(252,141,89);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(255,255,191);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(145,191,219);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div>'

# %% [markdown]
# ### cl.flipper( scale=None )
#
# Return the inverse of the color scale dictionary cl.scale

# %%
cl.flipper()['div']['3']['RdYlBu']
# Out:
# ['rgb(252,141,89)', 'rgb(255,255,191)', 'rgb(145,191,219)']

# %%
HTML(cl.to_html( {'RdYlBu 3 steps': cl.flipper()['div']['3']['RdYlBu']} ))
# Out:
# <div style="display:inline-block;padding:10px;"><div>RdYlBu 3 steps</div><div style="background-color:rgb(252,141,89);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(255,255,191);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(145,191,219);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div></div>

# %% [markdown]
# ### cl.interp( scale, r )
#
# Interpolate a color scale "scale" to a new one with length "r"

# %%
from IPython.display import HTML

HTML( cl.to_html( cl.to_hsl( cl.interp( cl.scales['11']['qual']['Paired'], 35 ) ) ) )
# Out:
# <div style="background-color:hsl(200.0, 52.0%, 77.0%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(201.1764705882353, 57.294117647058826%, 66.41176470588235%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(202.35294117647058, 62.588235294117645%, 55.82352941176471%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(203.52941176470588, 67.88235294117646%, 45.23529411764706%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(184.05882352941177, 67.70588235294117%, 46.11764705882353%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(150.8235294117647, 63.88235294117647%, 54.64705882352941%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(117.58823529411765, 60.058
# ...

# %% [markdown]
# ### All colors in cl.scales

# %%
# (in IPython notebook)
from IPython.display import HTML

HTML(cl.to_html( cl.scales ))
# Out:
# <hr><h3>10 colors</h3><h4>Diverging</h4><div style="display:inline-block;padding:10px;"><div>BrBG</div><div style="background-color:rgb(84,48,5);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(140,81,10);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(191,129,45);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(223,194,125);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(246,232,195);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(199,234,229);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(128,205,193);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:rgb(53,151,143);height:20px;width:20px;margin-bottom:0px;disp
# ...

# %% [markdown]
# ------------------
